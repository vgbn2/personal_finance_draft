# %% [markdown]
# # Data exploration

# %% [markdown]
# Research ladder fixture

# %%
from notebook_utils import load_json, print_verdict, repo_root, run_cli

# %%
summary = 'stale 1d rows remain'
summary

# %%
print_verdict('Data exploration', True, ['fixture ok'])

# %% [markdown]
# End
