# %% [markdown]
# # Model training

# %% [markdown]
# Research ladder fixture

# %%
from notebook_utils import load_json, print_verdict, repo_root, run_cli

# %%
strategy_draft = {'name': 'fixture_model'}
strategy_draft

# %%
print_verdict('Model training', True, ['fixture ok'])

# %% [markdown]
# End
