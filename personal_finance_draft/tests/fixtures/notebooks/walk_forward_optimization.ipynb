# %% [markdown]
# # Walk forward optimization

# %% [markdown]
# Research ladder fixture

# %%
from notebook_utils import load_json, print_verdict, repo_root, run_cli

# %%
note = 'stability threshold'
note

# %%
print_verdict('Walk forward optimization', True, ['fixture ok'])

# %% [markdown]
# End
