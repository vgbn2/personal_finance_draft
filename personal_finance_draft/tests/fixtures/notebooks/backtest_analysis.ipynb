# %% [markdown]
# # Backtest analysis

# %% [markdown]
# Research ladder fixture

# %%
from notebook_utils import load_json, print_verdict, repo_root, run_cli

# %%
analysis = {'status': 'ready'}
analysis

# %%
print_verdict('Backtest analysis', True, ['fixture ok'])

# %% [markdown]
# End
