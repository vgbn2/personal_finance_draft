# %% [markdown]
# # Feature importance

# %% [markdown]
# Research ladder fixture

# %%
from notebook_utils import load_json, print_verdict, repo_root, run_cli

# %%
top_feature = {'feature': 'momentum', 'score': 0.42}
top_feature

# %%
print_verdict('Feature importance', True, ['fixture ok'])

# %% [markdown]
# End
